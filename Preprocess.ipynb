# %%
import os
from PIL import Image
import numpy as np
import logging

# %%
# Setup logging
logging.basicConfig(filename='new_combine_labels.log', level=logging.ERROR)

def combine_binary_maps(binary_maps):
    binary_maps = np.array(binary_maps)  # Ensure shape is (N, H, W)
    num_labels = binary_maps.shape[0]
    class_indices = np.arange(1, num_labels + 1)[:, None, None]
    return np.sum(binary_maps * class_indices, axis=0)

# %%
# Collect tasks
label_list = os.listdir('./data/labels')
tasks = set()  # Use a set to avoid duplicates

for label in label_list:
    if '-annotation-' in label:
        task_name = label.split('-annotation-')[0]  # More specific split
        tasks.add(task_name)

tasks = sorted(tasks)  # Sort tasks for consistent processing
print(f"Detected tasks: {tasks}")
# Out:
# Detected tasks: ['task-100', 'task-101', 'task-102', 'task-103', 'task-104', 'task-105', 'task-106', 'task-107', 'task-108', 'task-109', 'task-110', 'task-111', 'task-112', 'task-113', 'task-114', 'task-115', 'task-116', 'task-117', 'task-118', 'task-119', 'task-120', 'task-121', 'task-122', 'task-123', 'task-124', 'task-125', 'task-126', 'task-127', 'task-128', 'task-129', 'task-130', 'task-131', 'task-132', 'task-133', 'task-134', 'task-135', 'task-136', 'task-137', 'task-138', 'task-139', 'task-140', 'task-141', 'task-142', 'task-143', 'task-144', 'task-145', 'task-146', 'task-147', 'task-148', 'task-149', 'task-150', 'task-151', 'task-152', 'task-153', 'task-154', 'task-155', 'task-156', 'task-157', 'task-158', 'task-159', 'task-160', 'task-161', 'task-162', 'task-163', 'task-164', 'task-165', 'task-166', 'task-167', 'task-168', 'task-169', 'task-170', 'task-171', 'task-172', 'task-173', 'task-174', 'task-175', 'task-176', 'task-177', 'task-178', 'task-179', 'task-180', 'task-181', 'task-182', 'task-183', 'task-184', 'task-185', 'task-186', 'task-187', 'task-188', 'task-189', 'task-190', 'task-191', 'task-192', 'task-193', 'task-194', 'task-195', 'task-196', 'task-197', 'task-198', 'task-199', 'task-200', 'task-201', 'task-202', 'task-203', 'task-204', 'task-205', 'task-206', 'task-207', 'task-208', 'task-209', 'task-210', 'task-211', 'task-212', 'task-213', 'task-214', 'task-215', 'task-216', 'task-217', 'task-218', 'task-219', 'task-220', 'task-221', 'task-222', 'task-223', 'task-224', 'task-225', 'task-226', 'task-227', 'task-228', 'task-229', 'task-230', 'task-231', 'task-232', 'task-233', 'task-234', 'task-235', 'task-236', 'task-237', 'task-238', 'task-239', 'task-240', 'task-241', 'task-242', 'task-243', 'task-244', 'task-245', 'task-246', 'task-247', 'task-248', 'task-249', 'task-250', 'task-251', 'task-252', 'task-253', 'task-254', 'task-255', 'task-256', 'task-257', 'task-258', 'task-259', 'task-260', 'task-261', 'task-262', 'task-263', 'task-264', 'task-265', 'task-266', 'task-267', 'task-268', 'task-269', 'task-270', 'task-271', 'task-272', 'task-273', 'task-274', 'task-275', 'task-276', 'task-277', 'task-278', 'task-279', 'task-280', 'task-281', 'task-282', 'task-283', 'task-284', 'task-285', 'task-286', 'task-287', 'task-288', 'task-289', 'task-290', 'task-291', 'task-292', 'task-293', 'task-294', 'task-295', 'task-296', 'task-297', 'task-298', 'task-299', 'task-300', 'task-301', 'task-302', 'task-303', 'task-304', 'task-305', 'task-306', 'task-307', 'task-308', 'task-309', 'task-31', 'task-310', 'task-311', 'task-312', 'task-313', 'task-314', 'task-315', 'task-316', 'task-317', 'task-318', 'task-319', 'task-32', 'task-320', 'task-321', 'task-322', 'task-323', 'task-324', 'task-325', 'task-326', 'task-327', 'task-328', 'task-329', 'task-33', 'task-330', 'task-331', 'task-332', 'task-333', 'task-334', 'task-335', 'task-336', 'task-337', 'task-338', 'task-339', 'task-34', 'task-340', 'task-341', 'task-342', 'task-343', 'task-344', 'task-345', 'task-346', 'task-347', 'task-348', 'task-349', 'task-35', 'task-350', 'task-351', 'task-352', 'task-353', 'task-354', 'task-355', 'task-356', 'task-357', 'task-358', 'task-359', 'task-36', 'task-360', 'task-361', 'task-362', 'task-363', 'task-364', 'task-365', 'task-366', 'task-367', 'task-368', 'task-369', 'task-37', 'task-370', 'task-371', 'task-372', 'task-373', 'task-374', 'task-375', 'task-376', 'task-377', 'task-378', 'task-379', 'task-38', 'task-380', 'task-381', 'task-382', 'task-383', 'task-384', 'task-385', 'task-386', 'task-387', 'task-388', 'task-389', 'task-39', 'task-390', 'task-391', 'task-392', 'task-393', 'task-394', 'task-395', 'task-396', 'task-397', 'task-398', 'task-399', 'task-40', 'task-400', 'task-401', 'task-402', 'task-403', 'task-404', 'task-405', 'task-406', 'task-407', 'task-408', 'task-409', 'task-41', 'task-410', 'task-411', 'task-412', 'task-413', 'task-414', 'task-415', 'task-416', 'task-417', 'task-418', 'task-419', 'task-42', 'task-420', ...

# %%
# Process each task
for task in tasks:
    try:
        labels = []
        binary_maps = []

        # Collect all label files for the current task
        for annotation in os.listdir('./data/labels/'):
            if annotation.startswith(task + "-"):  # Match more precisely
                labels.append(annotation)

        # Skip tasks with no matching labels
        if not labels:
            logging.error(f"No labels found for task: {task}")
            continue

        # Process each label file
        for label in labels:
            file_path = os.path.join('./data/labels/', label)
            try:
                binary_map = np.array(Image.open(file_path).convert("L"))
                binary_map = (binary_map > 0).astype(np.uint8)
                binary_maps.append(binary_map)
            except Exception as e:
                logging.error(f"Error processing file {file_path}: {e}")
                continue

        # Combine binary maps
        new_combined_label = combine_binary_maps(binary_maps)

        # Normalize combined label
        if new_combined_label.max() > 0:
            new_combined_label = (new_combined_label / new_combined_label.max() * 255).astype(np.uint8)

        # Save combined label
        combined_label_image = Image.fromarray(new_combined_label, mode='L')
        output_path = os.path.join('./data/new_combined_labels', f"{task}_combined.png")
        combined_label_image.save(output_path)
        print(f"Saved combined label for task {task} at {output_path}")

    except Exception as e:
        logging.error(f"Error processing task {task}: {e}")
        continue
# Out:
# Saved combined label for task task-100 at ./data/new_combined_labels\task-100_combined.png
# Saved combined label for task task-101 at ./data/new_combined_labels\task-101_combined.png
# Saved combined label for task task-102 at ./data/new_combined_labels\task-102_combined.png
# Saved combined label for task task-103 at ./data/new_combined_labels\task-103_combined.png
# Saved combined label for task task-104 at ./data/new_combined_labels\task-104_combined.png
# Saved combined label for task task-105 at ./data/new_combined_labels\task-105_combined.png
# Saved combined label for task task-106 at ./data/new_combined_labels\task-106_combined.png
# Saved combined label for task task-107 at ./data/new_combined_labels\task-107_combined.png
# Saved combined label for task task-108 at ./data/new_combined_labels\task-108_combined.png
# Saved combined label for task task-109 at ./data/new_combined_labels\task-109_combined.png
# Saved combined label for task task-110 at ./data/new_combined_labels\task-110_combined.png
# Saved combined label for task task-111 at ./data/new_combined_labels\task-111_combined.png
# Saved combined label for task task-112 at ./data/new_combined_labels\task-112_combined.png
# Saved combined label for task task-113 at ./data/new_combined_labels\task-113_combined.png
# Saved combined label for task task-114 at ./data/new_combined_labels\task-114_combined.png
# Saved combined label for task task-115 at ./data/new_combined_labels\task-115_combined.png
# Saved combined label for task task-116 at ./data/new_combined_labels\task-116_combined.png
# Saved combined label for task task-117 at ./data/new_combined_labels\task-117_combined.png
# Saved combined label for task task-118 at ./data/new_combined_labels\task-118_combined.png
# Saved combined label for task task-119 at ./data/new_combined_labels\task-119_combined.png
# Saved combined label for task task-120 at ./data/new_combined_labels\task-120_combined.png
# Saved combined label for task task-121 at ./data/new_combined_labels\task-121_combined.png
# Saved combined label for task task-122 at ./data/new_combined_labels\task-122_combined.png
# Saved combined label for task task-123 at ./data/new_combined_labels\task-123_combined.png
# Saved combined label for task task-124 at ./data/new_combined_labels\task-124_combined.png
# Saved combined label for task task-125 at ./data/new_combined_labels\task-125_combined.png
# Saved combined label for task task-126 at ./data/new_combined_labels\task-126_combined.png
# Saved combined label for task task-127 at ./data/new_combined_labels\task-127_combined.png
# Saved combined label for task task-128 at ./data/new_combined_labels\task-128_combined.png
# Saved combined label for task task-129 at ./data/new_combined_labels\task-129_combined.png
# Saved combined label for task task-130 at ./data/new_combined_labels\task-130_combined.png
# Saved combined label for task task-131 at ./data/new_combined_labels\task-131_combined.png
# Saved combined label for task task-132 at ./data/new_combined_labels\task-132_combined.png
# Saved combined label for task task-133 at ./data/new_combined_labels\task-133_combined.png
# Saved combined label for task task-134 at ./data/new_combined_labels\task-134_combined.png
# Saved combined label for task task-135 at ./data/new_combined_labels\task-135_combined.png
# Saved combined label for task task-136 at ./data/new_combined_labels\task-136_combined.png
# Saved combined label for task task-137 at ./data/new_combined_labels\task-137_combined.png
# Saved combined label for task task-138 at ./data/new_combined_labels\task-138_combined.png
# Saved combined label for task task-139 at ./data/new_combined_labels\task-139_combined.png
# Saved combined label for task task-140 at ./data/new_combined_labels\task-140_combined.png
# Saved combined label for task task-141 at ./data/new_combined_labels\task-141_combined.png
# Saved combined label for task task-142 at ./data/new_combined_labels\task-142_combined.png
# Saved combined label for task task-143 at ./data/new_combined_labels\task-143_combined.png
# Saved combined label for task task-144 at ./data/new_combined_labels\task-144_combined.png
# Saved combined label for task task-145 at ./data/new_combined_labels\task-145_combined.png
# Saved combined label for task task-146 at ./data/new_combined_labels\task-146_combined.png
# Saved combined label for task task-147 at ./data/new_combined_labels\task-147_combined.png
# Saved combined label for task task-148 at ./data/new_combined_labels\task-148_combined.png
# Saved combined label for task task-149 at ./data/new_combined_labels\task-149_combined.png
# Saved combined label for task task-150 at ./data/new_combined_labels\task-150_combined.png
# Saved combined label for task task-151 at ./data/new_combined_labels\task-151_combined.png
# Saved combined label for task task-152 at ./data/new_combined_labels\task-152_combined.png
# Saved combined label for task task-153 at ./data/new_combined_labels\task-153_combined.png
# Saved combined label for task task-154 at ./data/new_combined_labels\task-154_combined.png
# Saved combined label for task task-155 at ./data/new_combined_labels\task-155_combined.png
# Saved combined label for task task-156 at ./data/new_combined_labels\task-156_combined.png
# Saved combined label for task task-157 at ./data/new_combined_labels\task-157_combined.png
# Saved combined label for task task-158 at ./data/new_combined_labels\task-158_combined.png
# Saved combined label for task task-159 at ./data/new_combined_labels\task-159_combined.png
# Saved combined label for task task-160 at ./data/new_combined_labels\task-160_combined.png
# Saved combined label for task task-161 at ./data/new_combined_labels\task-161_combined.png
# Saved combined label for task task-162 at ./data/new_combined_labels\task-162_combined.png
# Saved combined label for task task-163 at ./data/new_combined_labels\task-163_combined.png
# Saved combined label for task task-164 at ./data/new_combined_labels\task-164_combined.png
# Saved combined label for task task-165 at ./data/new_combined_labels\task-165_combined.png
# Saved combined label for task task-166 at ./data/new_combined_labels\task-166_combined.png
# Saved combined label for task task-167 at ./data/new_combined_labels\task-167_combined.png
# Saved combined label for task task-168 at ./data/new_combined_labels\task-168_combined.png
# Saved combined label for task task-169 at ./data/new_combined_labels\task-169_combined.png
# Saved combined label for task task-170 at ./data/new_combined_labels\task-170_combined.png
# Saved combined label for task task-171 at ./data/new_combined_labels\task-171_combined.png
# Saved combined label for task task-172 at ./data/new_combined_labels\task-172_combined.png
# Saved combined label for task task-173 at ./data/new_combined_labels\task-173_combined.png
# Saved combined label for task task-174 at ./data/new_combined_labels\task-174_combined.png
# Saved combined label for task task-175 at ./data/new_combined_labels\task-175_combined.png
# Saved combined label for task task-176 at ./data/new_combined_labels\task-176_combined.png
# Saved combined label for task task-177 at ./data/new_combined_labels\task-177_combined.png
# Saved combined label for task task-178 at ./data/new_combined_labels\task-178_combined.png
# Saved combined label for task task-179 at ./data/new_combined_labels\task-179_combined.png
# Saved combined label for task task-180 at ./data/new_combined_labels\task-180_combined.png
# Saved combined label for task task-181 at ./data/new_combined_labels\task-181_combined.png
# Saved combined label for task task-182 at ./data/new_combined_labels\task-182_combined.png
# Saved combined label for task task-183 at ./data/new_combined_labels\task-183_combined.png
# Saved combined label for task task-184 at ./data/new_combined_labels\task-184_combined.png
# Saved combined label for task task-185 at ./data/new_combined_labels\task-185_combined.png
# Saved combined label for task task-186 at ./data/new_combined_labels\task-186_combined.png
# Saved combined label for task task-187 at ./data/new_combined_labels\task-187_combined.png
# Saved combined label for task task-188 at ./data/new_combined_labels\task-188_combined.png
# Saved combined label for task task-189 at ./data/new_combined_labels\task-189_combined.png
# Saved combined label for task task-190 at ./data/new_combined_labels\task-190_combined.png
# Saved combined label for task task-191 at ./data/new_combined_labels\task-191_combined.png
# Saved combined label for task task-192 at ./data/new_combined_labels\task-192_combined.png
# Saved combined label for task task-193 at ./data/new_combined_labels\task-193_combined.png
# Saved combined label for task task-194 at ./data/new_combined_labels\task-194_combined.png
# Saved combined label for task task-195 at ./data/new_combined_labels\task-195_combined.png
# Saved combined label for task task-196 at ./data/new_combined_labels\task-196_combined.png
# Saved combined label for task task-197 at ./data/new_combined_labels\task-197_combined.png
# Saved combined label for task task-198 at ./data/new_combined_labels\task-198_combined.png
# Saved combined label for task task-199 at ./data/new_combined_labels\task-199_combined.png
# Saved combined label for task task-200 at ./data/new_combined_labels\task-200_combined.png
# Saved combined label for task task-201 at ./data/new_combined_labels\task-201_combined.png
# Saved combined label for task task-202 at ./data/new_combined_labels\task-202_combined.png
# Saved combined label for task task-203 at ./data/new_combined_labels\task-203_combined.png
# Saved combined label for task task-204 at ./data/new_combined_labels\task-204_combined.png
# Saved combined label for task task-205 at ./data/new_combined_labels\task-205_combined.png
# Saved combined label for task task-206 at ./data/new_combined_labels\task-206_combined.png
# Saved combined label for task task-207 at ./data/new_combined_labels\task-207_combined.png
# Saved combined label for task task-208 at ./data/new_combined_labels\task-208_combined.png
# Saved combined label for task task-209 at ./data/new_combined_labels\task-209_combined.png
# Saved combined label for task task-210 at ./data/new_combined_labels\task-210_combined.png
# Saved combined label for task task-211 at ./data/new_combined_labels\task-211_combined.png
# Saved combined label for task task-212 at ./data/new_combined_labels\task-212_combined.png
# Saved combined label for task task-213 at ./data/new_combined_labels\task-213_combined.png
# Saved combined label for task task-214 at ./data/new_combined_labels\task-214_combined.png
# Saved combined label for task task-215 at ./data/new_combined_labels\task-215_combined.png
# Saved combined label for task task-216 at ./data/new_combined_labels\task-216_combined.png
# Saved combined label for task task-217 at ./data/new_combined_labels\task-217_combined.png
# Saved combined label for task task-218 at ./data/new_combined_labels\task-218_combined.png
# Saved combined label for task task-219 at ./data/new_combined_labels\task-219_combined.png
# Saved combined label for task task-220 at ./data/new_combined_labels\task-220_combined.png
# Saved combined label for task task-221 at ./data/new_combined_labels\task-221_combined.png
# Saved combined label for task task-222 at ./data/new_combined_labels\task-222_combined.png
# Saved combined label for task task-223 at ./data/new_combined_labels\task-223_combined.png
# Saved combined label for task task-224 at ./data/new_combined_labels\task-224_combined.png
# Saved combined label for task task-225 at ./data/new_combined_labels\task-225_combined.png
# Saved combined label for task task-226 at ./data/new_combined_labels\task-226_combined.png
# Saved combined label for task task-227 at ./data/new_combined_labels\task-227_combined.png
# Saved combined label for task task-228 at ./data/new_combined_labels\task-228_combined.png
# Saved combined label for task task-229 at ./data/new_combined_labels\task-229_combined.png
# Saved combined label for task task-230 at ./data/new_combined_labels\task-230_combined.png
# Saved combined label for task task-231 at ./data/new_combined_labels\task-231_combined.png
# Saved combined label for task task-232 at ./data/new_combined_labels\task-232_combined.png
# Saved combined label for task task-233 at ./data/new_combined_labels\task-233_combined.png
# Saved combined label for task task-234 at ./data/new_combined_labels\task-234_combined.png
# Saved combined label for task task-235 at ./data/new_combined_labels\task-235_combined.png
# Saved combined label for task task-236 at ./data/new_combined_labels\task-236_combined.png
# Saved combined label for task task-237 at ./data/new_combined_labels\task-237_combined.png
# Saved combined label for task task-238 at ./data/new_combined_labels\task-238_combined.png
# Saved combined label for task task-239 at ./data/new_combined_labels\task-239_combined.png
# Saved combined label for task task-240 at ./data/new_combined_labels\task-240_combined.png
# Saved combined label for task task-241 at ./data/new_combined_labels\task-241_combined.png
# Saved combined label for task task-242 at ./data/new_combined_labels\task-242_combined.png
# Saved combined label for task task-243 at ./data/new_combined_labels\task-243_combined.png
# Saved combined label for task task-244 at ./data/new_combined_labels\task-244_combined.png
# Saved combined label for task task-245 at ./data/new_combined_labels\task-245_combined.png
# Saved combined label for task task-246 at ./data/new_combined_labels\task-246_combined.png
# Saved combined label for task task-247 at ./data/new_combined_labels\task-247_combined.png
# Saved combined label for task task-248 at ./data/new_combined_labels\task-248_combined.png
# Saved combined label for task task-249 at ./data/new_combined_labels\task-249_combined.png
# Saved combined label for task task-250 at ./data/new_combined_labels\task-250_combined.png
# Saved combined label for task task-251 at ./data/new_combined_labels\task-251_combined.png
# Saved combined label for task task-252 at ./data/new_combined_labels\task-252_combined.png
# Saved combined label for task task-253 at ./data/new_combined_labels\task-253_combined.png
# Saved combined label for task task-254 at ./data/new_combined_labels\task-254_combined.png
# Saved combined label for task task-255 at ./data/new_combined_labels\task-255_combined.png
# Saved combined label for task task-256 at ./data/new_combined_labels\task-256_combined.png
# Saved combined label for task task-257 at ./data/new_combined_labels\task-257_combined.png
# Saved combined label for task task-258 at ./data/new_combined_labels\task-258_combined.png
# Saved combined label for task task-259 at ./data/new_combined_labels\task-259_combined.png
# Saved combined label for task task-260 at ./data/new_combined_labels\task-260_combined.png
# Saved combined label for task task-261 at ./data/new_combined_labels\task-261_combined.png
# Saved combined label for task task-262 at ./data/new_combined_labels\task-262_combined.png
# Saved combined label for task task-263 at ./data/new_combined_labels\task-263_combined.png
# Saved combined label for task task-264 at ./data/new_combined_labels\task-264_combined.png
# Saved combined label for task task-265 at ./data/new_combined_labels\task-265_combined.png
# Saved combined label for task task-266 at ./data/new_combined_labels\task-266_combined.png
# Saved combined label for task task-267 at ./data/new_combined_labels\task-267_combined.png
# Saved combined label for task task-268 at ./data/new_combined_labels\task-268_combined.png
# Saved combined label for task task-269 at ./data/new_combined_labels\task-269_combined.png
# Saved combined label for task task-270 at ./data/new_combined_labels\task-270_combined.png
# Saved combined label for task task-271 at ./data/new_combined_labels\task-271_combined.png
# Saved combined label for task task-272 at ./data/new_combined_labels\task-272_combined.png
# Saved combined label for task task-273 at ./data/new_combined_labels\task-273_combined.png
# Saved combined label for task task-274 at ./data/new_combined_labels\task-274_combined.png
# Saved combined label for task task-275 at ./data/new_combined_labels\task-275_combined.png
# Saved combined label for task task-276 at ./data/new_combined_labels\task-276_combined.png
# Saved combined label for task task-277 at ./data/new_combined_labels\task-277_combined.png
# Saved combined label for task task-278 at ./data/new_combined_labels\task-278_combined.png
# Saved combined label for task task-279 at ./data/new_combined_labels\task-279_combined.png
# Saved combined label for task task-280 at ./data/new_combined_labels\task-280_combined.png
# Saved combined label for task task-281 at ./data/new_combined_labels\task-281_combined.png
# Saved combined label for task task-282 at ./data/new_combined_labels\task-282_combined.png
# Saved combined label for task task-283 at ./data/new_combined_labels\task-283_combined.png
# Saved combined label for task task-284 at ./data/new_combined_labels\task-284_combined.png
# Saved combined label for task task-285 at ./data/new_combined_labels\task-285_combined.png
# Saved combined label for task task-286 at ./data/new_combined_labels\task-286_combined.png
# Saved combined label for task task-287 at ./data/new_combined_labels\task-287_combined.png
# Saved combined label for task task-288 at ./data/new_combined_labels\task-288_combined.png
# Saved combined label for task task-289 at ./data/new_combined_labels\task-289_combined.png
# Saved combined label for task task-290 at ./data/new_combined_labels\task-290_combined.png
# Saved combined label for task task-291 at ./data/new_combined_labels\task-291_combined.png
# Saved combined label for task task-292 at ./data/new_combined_labels\task-292_combined.png
# Saved combined label for task task-293 at ./data/new_combined_labels\task-293_combined.png
# Saved combined label for task task-294 at ./data/new_combined_labels\task-294_combined.png
# Saved combined label for task task-295 at ./data/new_combined_labels\task-295_combined.png
# Saved combined label for task task-296 at ./data/new_combined_labels\task-296_combined.png
# Saved combined label for task task-297 at ./data/new_combined_labels\task-297_combined.png
# Saved combined label for task task-298 at ./data/new_combined_labels\task-298_combined.png
# Saved combined label for task task-299 at ./data/new_combined_labels\task-299_combined.png
# Saved combined label for task task-300 at ./data/new_combined_labels\task-300_combined.png
# Saved combined label for task task-301 at ./data/new_combined_labels\task-301_combined.png
# Saved combined label for task task-302 at ./data/new_combined_labels\task-302_combined.png
# Saved combined label for task task-303 at ./data/new_combined_labels\task-303_combined.png
# Saved combined label for task task-304 at ./data/new_combined_labels\task-304_combined.png
# Saved combined label for task task-305 at ./data/new_combined_labels\task-305_combined.png
# Saved combined label for task task-306 at ./data/new_combined_labels\task-306_combined.png
# Saved combined label for task task-307 at ./data/new_combined_labels\task-307_combined.png
# Saved combined label for task task-308 at ./data/new_combined_labels\task-308_combined.png
# Saved combined label for task task-309 at ./data/new_combined_labels\task-309_combined.png
# Saved combined label for task task-31 at ./data/new_combined_labels\task-31_combined.png
# Saved combined label for task task-310 at ./data/new_combined_labels\task-310_combined.png
# Saved combined label for task task-311 at ./data/new_combined_labels\task-311_combined.png
# Saved combined label for task task-312 at ./data/new_combined_labels\task-312_combined.png
# Saved combined label for task task-313 at ./data/new_combined_labels\task-313_combined.png
# Saved combined label for task task-314 at ./data/new_combined_labels\task-314_combined.png
# Saved combined label for task task-315 at ./data/new_combined_labels\task-315_combined.png
# Saved combined label for task task-316 at ./data/new_combined_labels\task-316_combined.png
# Saved combined label for task task-317 at ./data/new_combined_labels\task-317_combined.png
# Saved combined label for task task-318 at ./data/new_combined_labels\task-318_combined.png
# Saved combined label for task task-319 at ./data/new_combined_labels\task-319_combined.png
# Saved combined label for task task-32 at ./data/new_combined_labels\task-32_combined.png
# Saved combined label for task task-320 at ./data/new_combined_labels\task-320_combined.png
# Saved combined label for task task-321 at ./data/new_combined_labels\task-321_combined.png
# Saved combined label for task task-322 at ./data/new_combined_labels\task-322_combined.png
# Saved combined label for task task-323 at ./data/new_combined_labels\task-323_combined.png
# Saved combined label for task task-324 at ./data/new_combined_labels\task-324_combined.png
# Saved combined label for task task-325 at ./data/new_combined_labels\task-325_combined.png
# Saved combined label for task task-326 at ./data/new_combined_labels\task-326_combined.png
# Saved combined label for task task-327 at ./data/new_combined_labels\task-327_combined.png
# Saved combined label for task task-328 at ./data/new_combined_labels\task-328_combined.png
# Saved combined label for task task-329 at ./data/new_combined_labels\task-329_combined.png
# Saved combined label for task task-33 at ./data/new_combined_labels\task-33_combined.png
# Saved combined label for task task-330 at ./data/new_combined_labels\task-330_combined.png
# Saved combined label for task task-331 at ./data/new_combined_labels\task-331_combined.png
# Saved combined label for task task-332 at ./data/new_combined_labels\task-332_combined.png
# Saved combined label for task task-333 at ./data/new_combined_labels\task-333_combined.png
# Saved combined label for task task-334 at ./data/new_combined_labels\task-334_combined.png
# Saved combined label for task task-335 at ./data/new_combined_labels\task-335_combined.png
# Saved combined label for task task-336 at ./data/new_combined_labels\task-336_combined.png
# Saved combined label for task task-337 at ./data/new_combined_labels\task-337_combined.png
# Saved combined label for task task-338 at ./data/new_combined_labels\task-338_combined.png
# Saved combined label for task task-339 at ./data/new_combined_labels\task-339_combined.png
# Saved combined label for task task-34 at ./data/new_combined_labels\task-34_combined.png
# Saved combined label for task task-340 at ./data/new_combined_labels\task-340_combined.png
# Saved combined label for task task-341 at ./data/new_combined_labels\task-341_combined.png
# Saved combined label for task task-342 at ./data/new_combined_labels\task-342_combined.png
# Saved combined label for task task-343 at ./data/new_combined_labels\task-343_combined.png
# Saved combined label for task task-344 at ./data/new_combined_labels\task-344_combined.png
# Saved combined label for task task-345 at ./data/new_combined_labels\task-345_combined.png
# Saved combined label for task task-346 at ./data/new_combined_labels\task-346_combined.png
# Saved combined label for task task-347 at ./data/new_combined_labels\task-347_combined.png
# Saved combined label for task task-348 at ./data/new_combined_labels\task-348_combined.png
# Saved combined label for task task-349 at ./data/new_combined_labels\task-349_combined.png
# Saved combined label for task task-35 at ./data/new_combined_labels\task-35_combined.png
# Saved combined label for task task-350 at ./data/new_combined_labels\task-350_combined.png
# Saved combined label for task task-351 at ./data/new_combined_labels\task-351_combined.png
# Saved combined label for task task-352 at ./data/new_combined_labels\task-352_combined.png
# Saved combined label for task task-353 at ./data/new_combined_labels\task-353_combined.png
# Saved combined label for task task-354 at ./data/new_combined_labels\task-354_combined.png
# Saved combined label for task task-355 at ./data/new_combined_labels\task-355_combined.png
# Saved combined label for task task-356 at ./data/new_combined_labels\task-356_combined.png
# Saved combined label for task task-357 at ./data/new_combined_labels\task-357_combined.png
# Saved combined label for task task-358 at ./data/new_combined_labels\task-358_combined.png
# Saved combined label for task task-359 at ./data/new_combined_labels\task-359_combined.png
# Saved combined label for task task-36 at ./data/new_combined_labels\task-36_combined.png
# Saved combined label for task task-360 at ./data/new_combined_labels\task-360_combined.png
# Saved combined label for task task-361 at ./data/new_combined_labels\task-361_combined.png
# Saved combined label for task task-362 at ./data/new_combined_labels\task-362_combined.png
# Saved combined label for task task-363 at ./data/new_combined_labels\task-363_combined.png
# Saved combined label for task task-364 at ./data/new_combined_labels\task-364_combined.png
# Saved combined label for task task-365 at ./data/new_combined_labels\task-365_combined.png
# Saved combined label for task task-366 at ./data/new_combined_labels\task-366_combined.png
# Saved combined label for task task-367 at ./data/new_combined_labels\task-367_combined.png
# Saved combined label for task task-368 at ./data/new_combined_labels\task-368_combined.png
# Saved combined label for task task-369 at ./data/new_combined_labels\task-369_combined.png
# Saved combined label for task task-37 at ./data/new_combined_labels\task-37_combined.png
# Saved combined label for task task-370 at ./data/new_combined_labels\task-370_combined.png
# Saved combined label for task task-371 at ./data/new_combined_labels\task-371_combined.png
# Saved combined label for task task-372 at ./data/new_combined_labels\task-372_combined.png
# Saved combined label for task task-373 at ./data/new_combined_labels\task-373_combined.png
# Saved combined label for task task-374 at ./data/new_combined_labels\task-374_combined.png
# Saved combined label for task task-375 at ./data/new_combined_labels\task-375_combined.png
# Saved combined label for task task-376 at ./data/new_combined_labels\task-376_combined.png
# Saved combined label for task task-377 at ./data/new_combined_labels\task-377_combined.png
# Saved combined label for task task-378 at ./data/new_combined_labels\task-378_combined.png
# Saved combined label for task task-379 at ./data/new_combined_labels\task-379_combined.png
# Saved combined label for task task-38 at ./data/new_combined_labels\task-38_combined.png
# Saved combined label for task task-380 at ./data/new_combined_labels\task-380_combined.png
# Saved combined label for task task-381 at ./data/new_combined_labels\task-381_combined.png
# Saved combined label for task task-382 at ./data/new_combined_labels\task-382_combined.png
# Saved combined label for task task-383 at ./data/new_combined_labels\task-383_combined.png
# Saved combined label for task task-384 at ./data/new_combined_labels\task-384_combined.png
# Saved combined label for task task-385 at ./data/new_combined_labels\task-385_combined.png
# Saved combined label for task task-386 at ./data/new_combined_labels\task-386_combined.png
# Saved combined label for task task-387 at ./data/new_combined_labels\task-387_combined.png
# Saved combined label for task task-388 at ./data/new_combined_labels\task-388_combined.png
# Saved combined label for task task-389 at ./data/new_combined_labels\task-389_combined.png
# Saved combined label for task task-39 at ./data/new_combined_labels\task-39_combined.png
# Saved combined label for task task-390 at ./data/new_combined_labels\task-390_combined.png
# Saved combined label for task task-391 at ./data/new_combined_labels\task-391_combined.png
# Saved combined label for task task-392 at ./data/new_combined_labels\task-392_combined.png
# Saved combined label for task task-393 at ./data/new_combined_labels\task-393_combined.png
# Saved combined label for task task-394 at ./data/new_combined_labels\task-394_combined.png
# Saved combined label for task task-395 at ./data/new_combined_labels\task-395_combined.png
# Saved combined label for task task-396 at ./data/new_combined_labels\task-396_combined.png
# Saved combined label for task task-397 at ./data/new_combined_labels\task-397_combined.png
# Saved combined label for task task-398 at ./data/new_combined_labels\task-398_combined.png
# Saved combined label for task task-399 at ./data/new_combined_labels\task-399_combined.png
# Saved combined label for task task-40 at ./data/new_combined_labels\task-40_combined.png
# Saved combined label for task task-400 at ./data/new_combined_labels\task-400_combined.png
# Saved combined label for task task-401 at ./data/new_combined_labels\task-401_combined.png
# Saved combined label for task task-402 at ./data/new_combined_labels\task-402_combined.png
# Saved combined label for task task-403 at ./data/new_combined_labels\task-403_combined.png
# Saved combined label for task task-404 at ./data/new_combined_labels\task-404_combined.png
# Saved combined label for task task-405 at ./data/new_combined_labels\task-405_combined.png
# Saved combined label for task task-406 at ./data/new_combined_labels\task-406_combined.png
# Saved combined label for task task-407 at ./data/new_combined_labels\task-407_combined.png
# Saved combined label for task task-408 at ./data/new_combined_labels\task-408_combined.png
# Saved combined label for task task-409 at ./data/new_combined_labels\task-409_combined.png
# Saved combined label for task task-41 at ./data/new_combined_labels\task-41_combined.png
# Saved combined label for task task-410 at ./data/new_combined_labels\task-410_combined.png
# Saved combined label for task task-411 at ./data/new_combined_labels\task-411_combined.png
# Saved combined label for task task-412 at ./data/new_combined_labels\task-412_combined.png
# Saved combined label for task task-413 at ./data/new_combined_labels\task-413_combined.png
# Saved combined label for task task-414 at ./data/new_combined_labels\task-414_combined.png
# Saved combined label for task task-415 at ./data/new_combined_labels\task-415_combined.png
# Saved combined label for task task-416 at ./data/new_combined_labels\task-416_combined.png
# Saved combined label for task task-417 at ./data/new_combined_labels\task-417_combined.png
# Saved combined label for task task-418 at ./data/new_combined_labels\task-418_combined.png
# Saved combined label for task task-419 at ./data/new_combined_labels\task-419_combined.png
# Saved combined label for task task-42 at ./data/new_combined_labels\task-42_combined.png
# Saved combined label for task task-420 at ./data/new_combined_labels\task-420_combined.png
# Saved combined label for task task-421 at ./data/new_combined_labels\task-421_combined.png
# Saved combined label for task task-422 at ./data/new_combined_labels\task-422_combined.png
# Saved combined label for task task-423 at ./data/new_combined_labels\task-423_combined.png
# Saved combined label for task task-424 at ./data/new_combined_labels\task-424_combined.png
# Saved combined label for task task-425 at ./data/new_combined_labels\task-425_combined.png
# Saved combined label for task task-426 at ./data/new_combined_labels\task-426_combined.png
# Saved combined label for task task-427 at ./data/new_combined_labels\task-427_combined.png
# Saved combined label for task task-428 at ./data/new_combined_labels\task-428_combined.png
# Saved combined label for task task-429 at ./data/new_combined_labels\task-429_combined.png
# Saved combined label for task task-43 at ./data/new_combined_labels\task-43_combined.png
# Saved combined label for task task-430 at ./data/new_combined_labels\task-430_combined.png
# Saved combined label for task task-431 at ./data/new_combined_labels\task-431_combined.png
# Saved combined label for task task-432 at ./data/new_combined_labels\task-432_combined.png
# Saved combined label for task task-433 at ./data/new_combined_labels\task-433_combined.png
# Saved combined label for task task-434 at ./data/new_combined_labels\task-434_combined.png
# Saved combined label for task task-435 at ./data/new_combined_labels\task-435_combined.png
# Saved combined label for task task-436 at ./data/new_combined_labels\task-436_combined.png
# Saved combined label for task task-437 at ./data/new_combined_labels\task-437_combined.png
# Saved combined label for task task-438 at ./data/new_combined_labels\task-438_combined.png
# Saved combined label for task task-439 at ./data/new_combined_labels\task-439_combined.png
# Saved combined label for task task-44 at ./data/new_combined_labels\task-44_combined.png
# Saved combined label for task task-440 at ./data/new_combined_labels\task-440_combined.png
# Saved combined label for task task-441 at ./data/new_combined_labels\task-441_combined.png
# Saved combined label for task task-442 at ./data/new_combined_labels\task-442_combined.png
# Saved combined label for task task-443 at ./data/new_combined_labels\task-443_combined.png
# Saved combined label for task task-444 at ./data/new_combined_labels\task-444_combined.png
# Saved combined label for task task-445 at ./data/new_combined_labels\task-445_combined.png
# Saved combined label for task task-446 at ./data/new_combined_labels\task-446_combined.png
# Saved combined label for task task-447 at ./data/new_combined_labels\task-447_combined.png
# Saved combined label for task task-448 at ./data/new_combined_labels\task-448_combined.png
# Saved combined label for task task-449 at ./data/new_combined_labels\task-449_combined.png
# Saved combined label for task task-45 at ./data/new_combined_labels\task-45_combined.png
# Saved combined label for task task-450 at ./data/new_combined_labels\task-450_combined.png
# Saved combined label for task task-451 at ./data/new_combined_labels\task-451_combined.png
# Saved combined label for task task-452 at ./data/new_combined_labels\task-452_combined.png
# Saved combined label for task task-453 at ./data/new_combined_labels\task-453_combined.png
# Saved combined label for task task-454 at ./data/new_combined_labels\task-454_combined.png
# Saved combined label for task task-455 at ./data/new_combined_labels\task-455_combined.png
# Saved combined label for task task-456 at ./data/new_combined_labels\task-456_combined.png
# Saved combined label for task task-457 at ./data/new_combined_labels\task-457_combined.png
# Saved combined label for task task-458 at ./data/new_combined_labels\task-458_combined.png
# Saved combined label for task task-459 at ./data/new_combined_labels\task-459_combined.png
# Saved combined label for task task-46 at ./data/new_combined_labels\task-46_combined.png
# Saved combined label for task task-460 at ./data/new_combined_labels\task-460_combined.png
# Saved combined label for task task-461 at ./data/new_combined_labels\task-461_combined.png
# Saved combined label for task task-462 at ./data/new_combined_labels\task-462_combined.png
# Saved combined label for task task-463 at ./data/new_combined_labels\task-463_combined.png
# Saved combined label for task task-464 at ./data/new_combined_labels\task-464_combined.png
# Saved combined label for task task-465 at ./data/new_combined_labels\task-465_combined.png
# Saved combined label for task task-466 at ./data/new_combined_labels\task-466_combined.png
# Saved combined label for task task-467 at ./data/new_combined_labels\task-467_combined.png
# Saved combined label for task task-468 at ./data/new_combined_labels\task-468_combined.png
# Saved combined label for task task-469 at ./data/new_combined_labels\task-469_combined.png
# Saved combined label for task task-47 at ./data/new_combined_labels\task-47_combined.png
# Saved combined label for task task-470 at ./data/new_combined_labels\task-470_combined.png
# Saved combined label for task task-471 at ./data/new_combined_labels\task-471_combined.png
# Saved combined label for task task-472 at ./data/new_combined_labels\task-472_combined.png
# Saved combined label for task task-473 at ./data/new_combined_labels\task-473_combined.png
# Saved combined label for task task-474 at ./data/new_combined_labels\task-474_combined.png
# Saved combined label for task task-475 at ./data/new_combined_labels\task-475_combined.png
# Saved combined label for task task-476 at ./data/new_combined_labels\task-476_combined.png
# Saved combined label for task task-477 at ./data/new_combined_labels\task-477_combined.png
# Saved combined label for task task-478 at ./data/new_combined_labels\task-478_combined.png
# Saved combined label for task task-479 at ./data/new_combined_labels\task-479_combined.png
# Saved combined label for task task-48 at ./data/new_combined_labels\task-48_combined.png
# Saved combined label for task task-480 at ./data/new_combined_labels\task-480_combined.png
# Saved combined label for task task-481 at ./data/new_combined_labels\task-481_combined.png
# Saved combined label for task task-482 at ./data/new_combined_labels\task-482_combined.png
# Saved combined label for task task-483 at ./data/new_combined_labels\task-483_combined.png
# Saved combined label for task task-484 at ./data/new_combined_labels\task-484_combined.png
# Saved combined label for task task-485 at ./data/new_combined_labels\task-485_combined.png
# Saved combined label for task task-486 at ./data/new_combined_labels\task-486_combined.png
# Saved combined label for task task-487 at ./data/new_combined_labels\task-487_combined.png
# Saved combined label for task task-488 at ./data/new_combined_labels\task-488_combined.png
# Saved combined label for task task-489 at ./data/new_combined_labels\task-489_combined.png
# Saved combined label for task task-49 at ./data/new_combined_labels\task-49_combined.png
# Saved combined label for task task-490 at ./data/new_combined_labels\task-490_combined.png
# Saved combined label for task task-491 at ./data/new_combined_labels\task-491_combined.png
# Saved combined label for task task-492 at ./data/new_combined_labels\task-492_combined.png
# Saved combined label for task task-493 at ./data/new_combined_labels\task-493_combined.png
# Saved combined label for task task-494 at ./data/new_combined_labels\task-494_combined.png
# Saved combined label for task task-495 at ./data/new_combined_labels\task-495_combined.png
# Saved combined label for task task-496 at ./data/new_combined_labels\task-496_combined.png
# Saved combined label for task task-497 at ./data/new_combined_labels\task-497_combined.png
# Saved combined label for task task-498 at ./data/new_combined_labels\task-498_combined.png
# Saved combined label for task task-499 at ./data/new_combined_labels\task-499_combined.png
# Saved combined label for task task-50 at ./data/new_combined_labels\task-50_combined.png
# Saved combined label for task task-500 at ./data/new_combined_labels\task-500_combined.png
# Saved combined label for task task-501 at ./data/new_combined_labels\task-501_combined.png
# Saved combined label for task task-502 at ./data/new_combined_labels\task-502_combined.png
# Saved combined label for task task-503 at ./data/new_combined_labels\task-503_combined.png
# Saved combined label for task task-504 at ./data/new_combined_labels\task-504_combined.png
# Saved combined label for task task-505 at ./data/new_combined_labels\task-505_combined.png
# Saved combined label for task task-506 at ./data/new_combined_labels\task-506_combined.png
# Saved combined label for task task-507 at ./data/new_combined_labels\task-507_combined.png
# Saved combined label for task task-508 at ./data/new_combined_labels\task-508_combined.png
# Saved combined label for task task-509 at ./data/new_combined_labels\task-509_combined.png
# Saved combined label for task task-51 at ./data/new_combined_labels\task-51_combined.png
# Saved combined label for task task-510 at ./data/new_combined_labels\task-510_combined.png
# Saved combined label for task task-511 at ./data/new_combined_labels\task-511_combined.png
# Saved combined label for task task-512 at ./data/new_combined_labels\task-512_combined.png
# Saved combined label for task task-513 at ./data/new_combined_labels\task-513_combined.png
# Saved combined label for task task-514 at ./data/new_combined_labels\task-514_combined.png
# Saved combined label for task task-515 at ./data/new_combined_labels\task-515_combined.png
# Saved combined label for task task-516 at ./data/new_combined_labels\task-516_combined.png
# Saved combined label for task task-517 at ./data/new_combined_labels\task-517_combined.png
# Saved combined label for task task-518 at ./data/new_combined_labels\task-518_combined.png
# Saved combined label for task task-519 at ./data/new_combined_labels\task-519_combined.png
# Saved combined label for task task-52 at ./data/new_combined_labels\task-52_combined.png
# Saved combined label for task task-520 at ./data/new_combined_labels\task-520_combined.png
# Saved combined label for task task-521 at ./data/new_combined_labels\task-521_combined.png
# Saved combined label for task task-522 at ./data/new_combined_labels\task-522_combined.png
# Saved combined label for task task-523 at ./data/new_combined_labels\task-523_combined.png
# Saved combined label for task task-524 at ./data/new_combined_labels\task-524_combined.png
# Saved combined label for task task-525 at ./data/new_combined_labels\task-525_combined.png
# Saved combined label for task task-526 at ./data/new_combined_labels\task-526_combined.png
# Saved combined label for task task-527 at ./data/new_combined_labels\task-527_combined.png
# Saved combined label for task task-528 at ./data/new_combined_labels\task-528_combined.png
# Saved combined label for task task-529 at ./data/new_combined_labels\task-529_combined.png
# Saved combined label for task task-53 at ./data/new_combined_labels\task-53_combined.png
# Saved combined label for task task-530 at ./data/new_combined_labels\task-530_combined.png
# Saved combined label for task task-531 at ./data/new_combined_labels\task-531_combined.png
# Saved combined label for task task-532 at ./data/new_combined_labels\task-532_combined.png
# Saved combined label for task task-533 at ./data/new_combined_labels\task-533_combined.png
# Saved combined label for task task-534 at ./data/new_combined_labels\task-534_combined.png
# Saved combined label for task task-535 at ./data/new_combined_labels\task-535_combined.png
# Saved combined label for task task-536 at ./data/new_combined_labels\task-536_combined.png
# Saved combined label for task task-537 at ./data/new_combined_labels\task-537_combined.png
# Saved combined label for task task-538 at ./data/new_combined_labels\task-538_combined.png
# Saved combined label for task task-539 at ./data/new_combined_labels\task-539_combined.png
# Saved combined label for task task-54 at ./data/new_combined_labels\task-54_combined.png
# Saved combined label for task task-540 at ./data/new_combined_labels\task-540_combined.png
# Saved combined label for task task-541 at ./data/new_combined_labels\task-541_combined.png
# Saved combined label for task task-542 at ./data/new_combined_labels\task-542_combined.png
# Saved combined label for task task-543 at ./data/new_combined_labels\task-543_combined.png
# Saved combined label for task task-544 at ./data/new_combined_labels\task-544_combined.png
# Saved combined label for task task-545 at ./data/new_combined_labels\task-545_combined.png
# Saved combined label for task task-546 at ./data/new_combined_labels\task-546_combined.png
# Saved combined label for task task-547 at ./data/new_combined_labels\task-547_combined.png
# Saved combined label for task task-548 at ./data/new_combined_labels\task-548_combined.png
# Saved combined label for task task-549 at ./data/new_combined_labels\task-549_combined.png
# Saved combined label for task task-55 at ./data/new_combined_labels\task-55_combined.png
# Saved combined label for task task-550 at ./data/new_combined_labels\task-550_combined.png
# Saved combined label for task task-551 at ./data/new_combined_labels\task-551_combined.png
# Saved combined label for task task-552 at ./data/new_combined_labels\task-552_combined.png
# Saved combined label for task task-553 at ./data/new_combined_labels\task-553_combined.png
# Saved combined label for task task-554 at ./data/new_combined_labels\task-554_combined.png
# Saved combined label for task task-555 at ./data/new_combined_labels\task-555_combined.png
# Saved combined label for task task-556 at ./data/new_combined_labels\task-556_combined.png
# Saved combined label for task task-557 at ./data/new_combined_labels\task-557_combined.png
# Saved combined label for task task-558 at ./data/new_combined_labels\task-558_combined.png
# Saved combined label for task task-559 at ./data/new_combined_labels\task-559_combined.png
# Saved combined label for task task-56 at ./data/new_combined_labels\task-56_combined.png
# Saved combined label for task task-560 at ./data/new_combined_labels\task-560_combined.png
# Saved combined label for task task-561 at ./data/new_combined_labels\task-561_combined.png
# Saved combined label for task task-562 at ./data/new_combined_labels\task-562_combined.png
# Saved combined label for task task-563 at ./data/new_combined_labels\task-563_combined.png
# Saved combined label for task task-564 at ./data/new_combined_labels\task-564_combined.png
# Saved combined label for task task-565 at ./data/new_combined_labels\task-565_combined.png
# Saved combined label for task task-566 at ./data/new_combined_labels\task-566_combined.png
# Saved combined label for task task-567 at ./data/new_combined_labels\task-567_combined.png
# Saved combined label for task task-568 at ./data/new_combined_labels\task-568_combined.png
# Saved combined label for task task-569 at ./data/new_combined_labels\task-569_combined.png
# Saved combined label for task task-57 at ./data/new_combined_labels\task-57_combined.png
# Saved combined label for task task-570 at ./data/new_combined_labels\task-570_combined.png
# Saved combined label for task task-571 at ./data/new_combined_labels\task-571_combined.png
# Saved combined label for task task-572 at ./data/new_combined_labels\task-572_combined.png
# Saved combined label for task task-573 at ./data/new_combined_labels\task-573_combined.png
# Saved combined label for task task-574 at ./data/new_combined_labels\task-574_combined.png
# Saved combined label for task task-575 at ./data/new_combined_labels\task-575_combined.png
# Saved combined label for task task-576 at ./data/new_combined_labels\task-576_combined.png
# Saved combined label for task task-577 at ./data/new_combined_labels\task-577_combined.png
# Saved combined label for task task-578 at ./data/new_combined_labels\task-578_combined.png
# Saved combined label for task task-579 at ./data/new_combined_labels\task-579_combined.png
# Saved combined label for task task-58 at ./data/new_combined_labels\task-58_combined.png
# Saved combined label for task task-580 at ./data/new_combined_labels\task-580_combined.png
# Saved combined label for task task-581 at ./data/new_combined_labels\task-581_combined.png
# Saved combined label for task task-582 at ./data/new_combined_labels\task-582_combined.png
# Saved combined label for task task-583 at ./data/new_combined_labels\task-583_combined.png
# Saved combined label for task task-584 at ./data/new_combined_labels\task-584_combined.png
# Saved combined label for task task-585 at ./data/new_combined_labels\task-585_combined.png
# Saved combined label for task task-586 at ./data/new_combined_labels\task-586_combined.png
# Saved combined label for task task-587 at ./data/new_combined_labels\task-587_combined.png
# Saved combined label for task task-588 at ./data/new_combined_labels\task-588_combined.png
# Saved combined label for task task-589 at ./data/new_combined_labels\task-589_combined.png
# Saved combined label for task task-59 at ./data/new_combined_labels\task-59_combined.png
# Saved combined label for task task-590 at ./data/new_combined_labels\task-590_combined.png
# Saved combined label for task task-591 at ./data/new_combined_labels\task-591_combined.png
# Saved combined label for task task-592 at ./data/new_combined_labels\task-592_combined.png
# Saved combined label for task task-593 at ./data/new_combined_labels\task-593_combined.png
# Saved combined label for task task-594 at ./data/new_combined_labels\task-594_combined.png
# Saved combined label for task task-595 at ./data/new_combined_labels\task-595_combined.png
# Saved combined label for task task-596 at ./data/new_combined_labels\task-596_combined.png
# Saved combined label for task task-597 at ./data/new_combined_labels\task-597_combined.png
# Saved combined label for task task-598 at ./data/new_combined_labels\task-598_combined.png
# Saved combined label for task task-599 at ./data/new_combined_labels\task-599_combined.png
# Saved combined label for task task-60 at ./data/new_combined_labels\task-60_combined.png
# Saved combined label for task task-600 at ./data/new_combined_labels\task-600_combined.png
# Saved combined label for task task-601 at ./data/new_combined_labels\task-601_combined.png
# Saved combined label for task task-602 at ./data/new_combined_labels\task-602_combined.png
# Saved combined label for task task-603 at ./data/new_combined_labels\task-603_combined.png
# Saved combined label for task task-604 at ./data/new_combined_labels\task-604_combined.png
# Saved combined label for task task-605 at ./data/new_combined_labels\task-605_combined.png
# Saved combined label for task task-606 at ./data/new_combined_labels\task-606_combined.png
# Saved combined label for task task-607 at ./data/new_combined_labels\task-607_combined.png
# Saved combined label for task task-608 at ./data/new_combined_labels\task-608_combined.png
# Saved combined label for task task-609 at ./data/new_combined_labels\task-609_combined.png
# Saved combined label for task task-61 at ./data/new_combined_labels\task-61_combined.png
# Saved combined label for task task-610 at ./data/new_combined_labels\task-610_combined.png
# Saved combined label for task task-611 at ./data/new_combined_labels\task-611_combined.png
# Saved combined label for task task-612 at ./data/new_combined_labels\task-612_combined.png
# Saved combined label for task task-613 at ./data/new_combined_labels\task-613_combined.png
# Saved combined label for task task-614 at ./data/new_combined_labels\task-614_combined.png
# Saved combined label for task task-615 at ./data/new_combined_labels\task-615_combined.png
# Saved combined label for task task-616 at ./data/new_combined_labels\task-616_combined.png
# Saved combined label for task task-617 at ./data/new_combined_labels\task-617_combined.png
# Saved combined label for task task-618 at ./data/new_combined_labels\task-618_combined.png
# Saved combined label for task task-619 at ./data/new_combined_labels\task-619_combined.png
# Saved combined label for task task-62 at ./data/new_combined_labels\task-62_combined.png
# Saved combined label for task task-620 at ./data/new_combined_labels\task-620_combined.png
# Saved combined label for task task-621 at ./data/new_combined_labels\task-621_combined.png
# Saved combined label for task task-622 at ./data/new_combined_labels\task-622_combined.png
# Saved combined label for task task-623 at ./data/new_combined_labels\task-623_combined.png
# Saved combined label for task task-624 at ./data/new_combined_labels\task-624_combined.png
# Saved combined label for task task-625 at ./data/new_combined_labels\task-625_combined.png
# Saved combined label for task task-626 at ./data/new_combined_labels\task-626_combined.png
# Saved combined label for task task-627 at ./data/new_combined_labels\task-627_combined.png
# Saved combined label for task task-628 at ./data/new_combined_labels\task-628_combined.png
# Saved combined label for task task-629 at ./data/new_combined_labels\task-629_combined.png
# Saved combined label for task task-63 at ./data/new_combined_labels\task-63_combined.png
# Saved combined label for task task-630 at ./data/new_combined_labels\task-630_combined.png
# Saved combined label for task task-64 at ./data/new_combined_labels\task-64_combined.png
# Saved combined label for task task-65 at ./data/new_combined_labels\task-65_combined.png
# Saved combined label for task task-66 at ./data/new_combined_labels\task-66_combined.png
# Saved combined label for task task-67 at ./data/new_combined_labels\task-67_combined.png
# Saved combined label for task task-68 at ./data/new_combined_labels\task-68_combined.png
# Saved combined label for task task-69 at ./data/new_combined_labels\task-69_combined.png
# Saved combined label for task task-70 at ./data/new_combined_labels\task-70_combined.png
# Saved combined label for task task-71 at ./data/new_combined_labels\task-71_combined.png
# Saved combined label for task task-72 at ./data/new_combined_labels\task-72_combined.png
# Saved combined label for task task-73 at ./data/new_combined_labels\task-73_combined.png
# Saved combined label for task task-74 at ./data/new_combined_labels\task-74_combined.png
# Saved combined label for task task-75 at ./data/new_combined_labels\task-75_combined.png
# Saved combined label for task task-76 at ./data/new_combined_labels\task-76_combined.png
# Saved combined label for task task-77 at ./data/new_combined_labels\task-77_combined.png
# Saved combined label for task task-78 at ./data/new_combined_labels\task-78_combined.png
# Saved combined label for task task-79 at ./data/new_combined_labels\task-79_combined.png
# Saved combined label for task task-80 at ./data/new_combined_labels\task-80_combined.png
# Saved combined label for task task-81 at ./data/new_combined_labels\task-81_combined.png
# Saved combined label for task task-82 at ./data/new_combined_labels\task-82_combined.png
# Saved combined label for task task-83 at ./data/new_combined_labels\task-83_combined.png
# Saved combined label for task task-84 at ./data/new_combined_labels\task-84_combined.png
# Saved combined label for task task-85 at ./data/new_combined_labels\task-85_combined.png
# Saved combined label for task task-86 at ./data/new_combined_labels\task-86_combined.png
# Saved combined label for task task-87 at ./data/new_combined_labels\task-87_combined.png
# Saved combined label for task task-88 at ./data/new_combined_labels\task-88_combined.png
# Saved combined label for task task-89 at ./data/new_combined_labels\task-89_combined.png
# Saved combined label for task task-90 at ./data/new_combined_labels\task-90_combined.png
# Saved combined label for task task-91 at ./data/new_combined_labels\task-91_combined.png
# Saved combined label for task task-92 at ./data/new_combined_labels\task-92_combined.png
# Saved combined label for task task-93 at ./data/new_combined_labels\task-93_combined.png
# Saved combined label for task task-94 at ./data/new_combined_labels\task-94_combined.png
# Saved combined label for task task-95 at ./data/new_combined_labels\task-95_combined.png
# Saved combined label for task task-96 at ./data/new_combined_labels\task-96_combined.png
# Saved combined label for task task-97 at ./data/new_combined_labels\task-97_combined.png
# Saved combined label for task task-98 at ./data/new_combined_labels\task-98_combined.png
# Saved combined label for task task-99 at ./data/new_combined_labels\task-99_combined.png
